# %%
# !python --version 

# %pip install -r requirements.txt
# Out:
# Python 3.11.3
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: autopep8==2.0.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: bcrypt==3.1.7 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (3.1.7)
# Requirement already satisfied: charset-normalizer==3.1.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: google-api-core==2.11.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (2.11.0)
# Requirement already satisfied: google-api-python-client==2.82.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (2.82.0)
# Requirement already satisfied: google-auth==2.16.2 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.16.2)
# Requirement already satisfied: google-auth-httplib2==0.1.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (0.1.0)
# Requirement already satisfied: google-auth-oauthlib==1.0.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: googleapis-common-protos==1.59.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (1.59.0)
# Requirement already satisfied: httplib2==0.22.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (0.22.0)
# Requirement already satisfied: imageio==2.27.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (2.27.0)
# Requirement already satisfied: Pillow==9.5.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (9.5.0)
# Requirement already satisfied: numpy==1.24.2 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (1.24.2)
# Requirement already satisfied: oauthlib==3.2.2 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (3.2.2)
# Requirement already satisfied: pandas==1.5.3 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (1.5.3)
# Requirement already satisfied: platformdirs==3.1.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (3.1.1)
# Requirement already satisfied: protobuf==4.22.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (4.22.1)
# Requirement already satisfied: pyasn1==0.4.8 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (0.2.8)
# Requirement already satisfied: pycodestyle==2.10.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (2.10.0)
# Requirement already satisfied: pylint==2.16.2 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 22)) (2.16.2)
# Requirement already satisfied: pyparsing==3.0.9 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 24)) (2.8.2)
# Requirement already satisfied: python-semantic-release==7.33.2 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 25)) (7.33.2)
# Requirement already satisfied: pytz==2022.7.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 26)) (2022.7.1)
# Requirement already satisfied: PyYAML==5.3.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 27)) (5.3.1)
# Requirement already satisfied: requests==2.28.2 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 28)) (2.28.2)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 29)) (1.3.1)
# Requirement already satisfied: requests-unixsocket==0.2.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (0.2.0)
# Requirement already satisfied: simplejson==3.16.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 31)) (3.16.0)
# Requirement already satisfied: tqdm==4.62.3 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 32)) (4.62.3)
# Requirement already satisfied: typing-extensions==4.5.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 33)) (4.5.0)
# Requirement already satisfied: uritemplate==4.1.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 34)) (4.1.1)
# Requirement already satisfied: urllib3==1.25.8 in /home/minibear3e/.local/lib/python3.11/site-packages (from -r requirements.txt (line 35)) (1.25.8)
# Requirement already satisfied: cffi>=1.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from bcrypt==3.1.7->-r requirements.txt (line 2)) (1.15.1)
# Requirement already satisfied: six>=1.4.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from bcrypt==3.1.7->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from google-auth==2.16.2->-r requirements.txt (line 6)) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/minibear3e/.local/lib/python3.11/site-packages (from google-auth==2.16.2->-r requirements.txt (line 6)) (4.9)
# Requirement already satisfied: astroid<=2.16.0-dev0,>=2.14.2 in /home/minibear3e/.local/lib/python3.11/site-packages (from pylint==2.16.2->-r requirements.txt (line 22)) (2.15.1)
# Requirement already satisfied: isort<6,>=4.2.5 in /home/minibear3e/.local/lib/python3.11/site-packages (from pylint==2.16.2->-r requirements.txt (line 22)) (5.12.0)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /home/minibear3e/.local/lib/python3.11/site-packages (from pylint==2.16.2->-r requirements.txt (line 22)) (0.7.0)
# Requirement already satisfied: tomlkit>=0.10.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from pylint==2.16.2->-r requirements.txt (line 22)) (0.11.7)
# Requirement already satisfied: dill>=0.3.6 in /home/minibear3e/.local/lib/python3.11/site-packages (from pylint==2.16.2->-r requirements.txt (line 22)) (0.3.6)
# Requirement already satisfied: click<9,>=7 in /usr/lib/python3/dist-packages (from python-semantic-release==7.33.2->-r requirements.txt (line 25)) (7.0)
# Requirement already satisfied: click-log<1,>=0.3 in /home/minibear3e/.local/lib/python3.11/site-packages (from python-semantic-release==7.33.2->-r requirements.txt (line 25)) (0.4.0)
# Requirement already satisfied: gitpython<4,>=3.0.8 in /home/minibear3e/.local/lib/python3.11/site-packages (from python-semantic-release==7.33.2->-r requirements.txt (line 25)) (3.1.31)
# Requirement already satisfied: invoke<2,>=1.4.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from python-semantic-release==7.33.2->-r requirements.txt (line 25)) (1.7.3)
# Requirement already satisfied: semver<3,>=2.10 in /home/minibear3e/.local/lib/python3.11/site-packages (from python-semantic-release==7.33.2->-r requirements.txt (line 25)) (2.13.0)
# Requirement already satisfied: twine<4,>=3 in /home/minibear3e/.local/lib/python3.11/site-packages (from python-semantic-release==7.33.2->-r requirements.txt (line 25)) (3.7.1)
# Requirement already satisfied: wheel in /home/minibear3e/.local/lib/python3.11/site-packages (from python-semantic-release==7.33.2->-r requirements.txt (line 25)) (0.40.0)
# Requirement already satisfied: python-gitlab<4,>=2 in /home/minibear3e/.local/lib/python3.11/site-packages (from python-semantic-release==7.33.2->-r requirements.txt (line 25)) (3.13.0)
# Requirement already satisfied: dotty-dict<2,>=1.3.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from python-semantic-release==7.33.2->-r requirements.txt (line 25)) (1.3.1)
# Requirement already satisfied: packaging in /home/minibear3e/.local/lib/python3.11/site-packages (from python-semantic-release==7.33.2->-r requirements.txt (line 25)) (23.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/minibear3e/.local/lib/python3.11/site-packages (from requests==2.28.2->-r requirements.txt (line 28)) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/minibear3e/.local/lib/python3.11/site-packages (from requests==2.28.2->-r requirements.txt (line 28)) (2022.12.7)
# Requirement already satisfied: lazy-object-proxy>=1.4.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from astroid<=2.16.0-dev0,>=2.14.2->pylint==2.16.2->-r requirements.txt (line 22)) (1.9.0)
# Requirement already satisfied: wrapt<2,>=1.14 in /home/minibear3e/.local/lib/python3.11/site-packages (from astroid<=2.16.0-dev0,>=2.14.2->pylint==2.16.2->-r requirements.txt (line 22)) (1.15.0)
# Requirement already satisfied: pycparser in /home/minibear3e/.local/lib/python3.11/site-packages (from cffi>=1.1->bcrypt==3.1.7->-r requirements.txt (line 2)) (2.21)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from gitpython<4,>=3.0.8->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (4.0.10)
# Requirement already satisfied: requests-toolbelt>=0.10.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from python-gitlab<4,>=2->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (0.10.1)
# Requirement already satisfied: pkginfo>=1.8.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (1.9.6)
# Requirement already satisfied: readme-renderer>=21.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (37.3)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/minibear3e/.local/lib/python3.11/site-packages (from twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (6.1.0)
# Requirement already satisfied: keyring>=15.1 in /usr/lib/python3/dist-packages (from twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (18.0.1)
# Requirement already satisfied: rfc3986>=1.4.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (2.0.0)
# Requirement already satisfied: colorama>=0.4.3 in /usr/lib/python3/dist-packages (from twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (0.4.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.0.8->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/minibear3e/.local/lib/python3.11/site-packages (from importlib-metadata>=3.6->twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (3.15.0)
# Requirement already satisfied: secretstorage in /usr/lib/python3/dist-packages (from keyring>=15.1->twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (2.3.1)
# Requirement already satisfied: bleach>=2.1.0 in /home/minibear3e/.local/lib/python3.11/site-packages (from readme-renderer>=21.0->twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (6.0.0)
# Requirement already satisfied: docutils>=0.13.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from readme-renderer>=21.0->twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (0.19)
# Requirement already satisfied: Pygments>=2.5.1 in /home/minibear3e/.local/lib/python3.11/site-packages (from readme-renderer>=21.0->twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (2.14.0)
# Requirement already satisfied: webencodings in /home/minibear3e/.local/lib/python3.11/site-packages (from bleach>=2.1.0->readme-renderer>=21.0->twine<4,>=3->python-semantic-release==7.33.2->-r requirements.txt (line 25)) (0.5.1)
#
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
""" Main Module """
from time import time

from dotenv import load_dotenv

from libs.man_mirror import ManMirror
from libs.my_novel import MyNovel
from libs.upload_google_drive import generate_drive_manga_exists, upload_to_drive
from libs.upload_google_drive.manga_result import show_manga_updated

# sys.path.append("./libs")
# sys.path.append("./libs/upload_google_drive")


load_dotenv()

MAX_WORKERS = 1


def download_man_mirror_manual() -> None:
    cartoons = [
        {
            "cartoon_name": "เทพมรณะ",
            "cartoon_id": 22,
            "chapters": [
                {
                    "chapter_name": "0",
                },
                {
                    "chapter_name": "1",
                },
                {
                    "chapter_name": "2",
                },
                {
                    "chapter_name": "3",
                },
                {
                    "chapter_name": "4",
                },
                {
                    "chapter_name": "5",
                },
            ]
        }
    ]

    man_mirror = ManMirror()

    for cartoon in cartoons:
        cartoon_name = cartoon["cartoon_name"]
        cartoon_id = cartoon["cartoon_id"]
        manga_exists_json = generate_drive_manga_exists(force_update=True)

        for chapter in cartoon['chapters']:
            chapter_name = chapter["chapter_name"]
            # image_paths = chapter["image_paths"]
            man_mirror.download_manual(cartoon_id=cartoon_id,  cartoon_name=cartoon_name,
                                       chapter=chapter_name, manga_exists_json=manga_exists_json)


def download_man_mirror():
    man_mirror_cartoons = [
        ['เลเวลอัพไม่จำกัด', 1, 138, 146],
        ['สุดยอดจอมยุทธ', 7, 1, 118],
        ['ดาบวายุอัสนี', 19, 21, 72],
        ['จ้าวสงคราม', 3, 65, 134],
        ['มือกระบี่ไร้พ่าย', 5, 100, 159],
        # ['จิตวิญญาณวายุ', 16, 1, 76],
        # ['โกแซม นักรบในตำนาน', 12, 65, 66],
        ['บัณฑิตหวนคืน', 8, 1, 144],  # max 133
        ['เส้นทางสู่สวรรค์', 21, 35, 70],
        ['มังกรพิษ', 6, 120, 131],
        # ['หนึ่งในใต้หล้า', 10, 1, 111],  # max 100
        ['ตำนานกระบี่อุดร', 9, 150, 154],
        ['เทพมรณะ', 22, 1, 38],
        # ['เทพอัสนี', 11, 1, 141],
        ['ทายาทจอมมาร', 2, 1, 81],
        ['ทายาทเทพธนู', 20, 1, 50],
        ['ขุนศึก', 24, 0, 53],
        ['เมื่อผมดันหยิบมือถือจากโลกอื่น', 23, 1, 30]
    ]

    man_mirror = ManMirror()
    manga_exists_json = generate_drive_manga_exists(
        force_update=True, project_name=man_mirror.root)
    for cartoon_name, cartoon_id, latest_chapter, max_chapter in man_mirror_cartoons:
        print(
            f'\ncartoon_name: {cartoon_name}\tkey: {cartoon_id}\tlatest_chapter: {latest_chapter}\tmax_chapter: {max_chapter}')

        man_mirror.download_cartoons(
            cartoon_name,
            cartoon_id,
            first_chapter=latest_chapter,
            max_chapter=max_chapter,
            manga_exists_json=manga_exists_json,
            max_workers=MAX_WORKERS
        )
    upload_to_drive(
        project_name=man_mirror.root)


def download_my_novel():
    my_novel_cartoons = [
        # ['Against the Gods - อสูรพลิกฟ้า', '6EvFPzipwmnKxlZMqhjs', 423],
        ['Cultivator vs Superhero (ทันจีน)', '6yeQcr6kL14A96eUwKZA', 250],
        ['Tales of Demon and Gods', 'E8XDEk8Dv9vbchSGtF5n', 419],
        ['Infinite Mage', '63b2a71156baafb4e8213126', 1]
    ]
    my_novel = MyNovel()
    manga_exists_json = generate_drive_manga_exists(
        force_update=True,  project_name=my_novel.root)
    for cartoon_name, cartoon_id, latest_chapter in my_novel_cartoons:

        print(
            f'\ncartoon_name: {cartoon_name}\tkey: {cartoon_id}\tlatest_chapter: {latest_chapter}')
        my_novel.download_cartoons(cartoon_id, start_ep_index=latest_chapter,
                                   manga_exists_json=manga_exists_json, max_workers=MAX_WORKERS)
    upload_to_drive(project_name=my_novel.root)


def function_execute_time(name: str, cb):
    start_time: float = time()
    cb()
    print(f"\n[Execute Time] {name} | {time() - start_time} seconds")

# %%
def run():
    ENABLE_DOWNLOAD_MAM_MIRROR = True
    ENABLE_DOWNLOAD_MAM_MIRROR_MANUAL = False
    ENABLE_DOWNLOAD_MY_NOVEL = True
    # manga_exists_json = generate_drive_manga_exists(force_update=True, logging=False)
    # generate_drive_manga_exists(force_update=True)
    # function_execute_time('show_manga_updated',show_manga_updated)
    # return

    if ENABLE_DOWNLOAD_MAM_MIRROR:
        function_execute_time('download_man_mirror', download_man_mirror)

    if ENABLE_DOWNLOAD_MAM_MIRROR_MANUAL:
        function_execute_time('download_man_mirror_manual',
                              download_man_mirror_manual)

    if ENABLE_DOWNLOAD_MY_NOVEL:
        function_execute_time('download_my_novel', download_my_novel)

    function_execute_time('upload_to_drive all', upload_to_drive)

    def tmp_x() -> None:
        generate_drive_manga_exists(force_update=True)

    function_execute_time('generate_drive_manga_exists', tmp_x)

    function_execute_time('show_manga_updated', show_manga_updated)


function_execute_time('execute download manga', run)

# %%
def run():
    function_execute_time('download_man_mirror', download_man_mirror)

    function_execute_time('download_man_mirror_manual',
                            download_man_mirror_manual)

    function_execute_time('download_my_novel', download_my_novel)


if __name__ == "__main__":
    function_execute_time('execute download manga', run)

# %%
# def run():
#     function_execute_time('download_man_mirror', download_man_mirror)

#     function_execute_time('download_man_mirror_manual',
#                             download_man_mirror_manual)

#     function_execute_time('download_my_novel', download_my_novel)

#     function_execute_time('upload_to_drive all', upload_to_drive)

# if __name__ == "__main__":
#     function_execute_time('execute download manga', run)

# %% [markdown]
# ### Update Manga Exists

# %%
function_execute_time('upload_to_drive all', upload_to_drive)

def tmp_x() -> None:
    generate_drive_manga_exists(force_update=True)

function_execute_time('generate_drive_manga_exists', tmp_x)

function_execute_time('show_manga_updated', show_manga_updated)
